# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options
import time
from bs4 import BeautifulSoup 
import pandas as pd
import numpy as np
import re
from random import randrange
from tqdm import tqdm #progress bar

# %%
chrome_options = webdriver.ChromeOptions()
prefs = {"profile.managed_default_content_settings.images": 2}
chrome_options.add_experimental_option("prefs", prefs)

driver = webdriver.Chrome(ChromeDriverManager().install(), chrome_options=chrome_options)
# Out:
# C:\Users\akvil\AppData\Local\Temp\ipykernel_2344\345066382.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(ChromeDriverManager().install(), chrome_options=chrome_options)
# C:\Users\akvil\AppData\Local\Temp\ipykernel_2344\345066382.py:5: DeprecationWarning: use options instead of chrome_options
#   driver = webdriver.Chrome(ChromeDriverManager().install(), chrome_options=chrome_options)

# %%
starting_link_to_scrape = "https://autoplius.lt/"
driver.get(starting_link_to_scrape)
time.sleep(2)
base_source = driver.page_source
base_soup = BeautifulSoup(base_source, 'html.parser')

# %%
base_soup
# Out:
# <html lang="lt"><head>
# <meta charset="utf-8"/>
# <meta content="Automobiliai, naudoti automobiliai, nauji automobiliai, auto skelbimai, parduodami automobiliai, automobiliu skelbimai." name="keywords"/>
# <meta content="Automobilių skelbimai. Nauji ir naudoti automobiliai bei kitos transporto priemonės vienoje vietoje. Parduodami ir nuomojami automobiliai." name="description"/>
# <meta content="website" property="og:type"/>
# <meta content="https://autoplius.lt/" property="og:url"/>
# <meta content="Automobilių skelbimai Nr.1 - Automobiliai, motociklai, dalys, technika - Autoplius.lt" property="og:title"/>
# <meta content="Automobilių skelbimai. Nauji ir naudoti automobiliai bei kitos transporto priemonės vienoje vietoje. Parduodami ir nuomojami automobiliai." property="og:description"/>
# <meta content="Automobilių skelbimai Nr.1 - Automobiliai, motociklai, dalys, technika - Autoplius.lt" name="twitter:title"/>
# ...

# %%
#make_list = base_soup.findAll("div", class_="dropdown-option js-option")
make_list = base_soup.findAll("div", class_="input-select js-make")[0]
make_list
# Out:
# <div class="input-select js-make" data-placeholder="−" data-user="" data-value="">
# <input class="js-value-container" name="make_id" type="hidden" value=""/>
# <div class="display-input js-placeholder" tabindex="0">
# <div class="value" style="display: none;"></div>
# <div class="placeholder" style="display: block;">−</div>
# </div>
# <div class="clear-btn"></div>
# <div class="dropdown js-dropdown">
# <div class="dropdown-filter js-filter">
# <input tabindex="-1" type="text" value=""/>
# </div>
# <div class="dropdown-options js-options">
# <div class="dropdown-option js-option" data-badge="9" data-title="-Kita-" data-value="106">
# <div class="title">-Kita-</div>
# <div class="badge">9</div>
# </div>
# <div class="dropdown-option js-option disabled" data-badge="0" data-title="AC" data-value="105">
# <div class="title">AC</div>
# <div class="badge">0</div>
# </div>
# <div class="dropdown-option js-option" data-badge="8" data-title="Acura" data-value="104">
# ...

# %%
type(make_list)[1]
# Out:
# bs4.element.ResultSet[1]

# %%
one_make_div = make_list.find_all("div", class_="title")
one_make_div
# Out:
# [<div class="title">-Kita-</div>,
#  <div class="title">AC</div>,
#  <div class="title">Acura</div>,
#  <div class="title">Aixam</div>,
#  <div class="title">Alfa Romeo</div>,
#  <div class="title">Alke</div>,
#  <div class="title">Alpina</div>,
#  <div class="title">Alpine</div>,
#  <div class="title">AMC</div>,
#  <div class="title">ARO</div>,
#  <div class="title">Asia</div>,
#  <div class="title">Aston Martin</div>,
#  <div class="title">Audi</div>,
#  <div class="title">Austin Rover</div>,
#  <div class="title">Austin-Healey</div>,
#  <div class="title">BELLIER</div>,
#  <div class="title">Bentley</div>,
#  <div class="title">BMW</div>,
#  <div class="title">Bolloré</div>,
#  <div class="title">Briliance</div>,
#  <div class="title">Bugatti</div>,
#  <div class="title">Buick</div>,
#  <div class="title">BYD</div>,
#  <div class="title">Cadillac</div>,
#  <div class="title">Chatenet</div>,
#  <div class="title">Chevrolet</div>,
#  <div class="title">Chrysler</div>,
# ...

# %%
make_string = "(//button[contains(text('Audi'),'Ieškoti')]" #we need find the element that we want to click and input a value to it
make_string
# Out:
# "(//button[contains(text('Audi'),'Ieškoti')]"

# %%
buton=driver.find_element(by="XPATH", make_string)
# Out:
#   Cell In [55], line 1
#     buton=driver.find_element(by="XPATH", make_string)
#                                                      ^
# SyntaxError: positional argument follows keyword argument
